# %% [markdown]
# # Stem Plot

# %%
import matplotlib.pyplot as plt

# %%
x=[2,4,3,2,5,6,7,8]
y=[1,2,3,1,2,3,2,1]
plt.stem(x,y,linefmt=":",markerfmt="ro",bottom=1,basefmt="green",label="stem plot",use_line_collection=False,orientation="vertical")
plt.legend(loc=1,fontsize=13)
# Out:
# C:\Users\Ashish Kumar Singh\AppData\Local\Temp\ipykernel_18928\3158791953.py:3: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem(x,y,linefmt=":",markerfmt="ro",bottom=1,basefmt="green",label="stem plot",use_line_collection=False,orientation="vertical")
