# %% [markdown]
# ImbalancedDataset

# %%
import pandas as pd

# %%
dataset=pd.read_csv("datasetlinearRegression.csv")
dataset.head(10)
# Out:
#    Age  salary  Purchased
# 0   35   30477          0
# 1   46   48256          1
# 2   30   27712          1
# 3   52   35573          1
# 4   32   25271          1
# 5   25   48597          1
# 6   28   20625          1
# 7   33   44174          1
# 8   43   46206          0
# 9   49   23612          1

# %%
dataset["Purchased"].value_counts()
# Out:
# Purchased
# 1    328
# 0    172
# Name: count, dtype: int64

# %%
x=dataset.iloc[:,:-1]
y=dataset["Purchased"]

# %%
 from sklearn.model_selection import train_test_split

# %%
 x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=42)

# %%
 from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test,y_test)*100
# Out:
# -3.1824512665661553

# %%
lr.predict([[43,46206]])
# Out:
# C:\Users\Ashish Kumar Singh\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([0.61562249])
